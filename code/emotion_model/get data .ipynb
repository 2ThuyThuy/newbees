# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil

# %%
len(glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/train_crop_align/*.jpg'))
# Out:
# 11707

# %%
glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/*')
# Out:
# ['/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Anger',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Neutral',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Disgust',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Sadness',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Surprise',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Fear',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Happiness']

# %%
single_label = pd.read_csv('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/single_label.csv',)

# %%
single_label.columns.values
# Out:
# array(['file_name', 'height', 'width', 'bbox', 'age', 'race', 'masked',
#        'skintone', 'emotion', 'gender'], dtype=object)

# %%
single_label.head()
# Out:
#        file_name  height  width  \
# 0  100013282.jpg    1333   2000
# 1  100016175.jpg    1333   2000
# 2   10004189.jpg    2000   1333
# 3  100104600.jpg    2000   1333
# 4   10012376.jpg    2000   1333
#
#                                                 bbox     age       race  \
# 0  [934.0000000000097, 144.82228672769534, 238.24...  20-30s  Caucasian
# 1  [1094.0513571635438, 422.91772295627203, 55.45...  20-30s  Caucasian
# 2  [419.93871061403877, 269.1250391680045, 377.19...  20-30s  Mongoloid
# 3  [549.169724453414, 92.52040334013152, 306.8821...  20-30s  Caucasian
# 4  [640.2165901410499, 619.7806050101991, 359.991...  20-30s  Mongoloid
#
#      masked   skintone    emotion  gender
# 0  unmasked  mid-light    Neutral    Male
# 1  unmasked      light    Neutral    Male
# 2  unmasked      light  Happiness  Female
# 3  unmasked  mid-light  Happiness  Female
# 4  unmasked      light  Happiness  Female

# %%
unmark_df = single_label[single_label['masked'] == 'unmasked'].reset_index(drop=True)

# %%
unmark_df['emotion'].value_counts()
# Out:
# Happiness    7171
# Neutral      3443
# Sadness       270
# Surprise      229
# Anger         213
# Disgust        95
# Fear           77
# Name: emotion, dtype: int64

# %%
unmark_df[unmark_df['emotion'] == 'Fear']
# Out:
#             file_name  height  width  \
# 49      101346736.jpg    1330   2000
# 100     102630150.jpg    1125   2000
# 197     105010109.jpg    1333   2000
# 296     108119733.jpg    1333   2000
# 420      12330138.jpg    1333   2000
# ...               ...     ...    ...
# 9753     92891172.jpg    1365   2000
# 9776     93415073.jpg    1333   2000
# 9892     94928158.jpg    1334   2000
# 9960     95886074.jpg    1333   2000
# 10948  image_2491.jpg    1024   1024
#
#                                                     bbox     age       race  \
# 49     [1053.759628297167, 473.92051383301157, 125.02...     Kid  Mongoloid
# 100    [888.1321433034028, 242.9852574162042, 279.231...  Senior  Caucasian
# 197    [658.9605341380777, 228.9335200510728, 165.656...  20-30s  Caucasian
# 296    [587.0356914723617, 193.29720399128254, 354.31...  20-30s  Mongoloid
# 420    [1181.0015003750832, 186.99999999999744, 183.9...  20-30s  Mongoloid
# ...

# %%
save_dir = glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/*')

# %%
save_dir
# Out:
# ['/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Anger',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Neutral',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Disgust',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Sadness',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Surprise',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Fear',
#  '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/Happiness']

# %%
dir_save = '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/'

# %%
unmark_df['emotion'].value_counts()
# Out:
# Happiness    7171
# Neutral      3443
# Sadness       270
# Surprise      229
# Anger         213
# Disgust        95
# Fear           77
# Name: emotion, dtype: int64

# %%
emotion_class = unmark_df['emotion'].value_counts().index
emotion_class
# Out:
# Index(['Happiness', 'Neutral', 'Sadness', 'Surprise', 'Anger', 'Disgust',
#        'Fear'],
#       dtype='object')

# %%
unmark_df
# Out:
#             file_name  height  width  \
# 0       100013282.jpg    1333   2000
# 1       100016175.jpg    1333   2000
# 2        10004189.jpg    2000   1333
# 3       100104600.jpg    2000   1333
# 4        10012376.jpg    2000   1333
# ...               ...     ...    ...
# 11493  image_2713.jpg    1024   1024
# 11494  image_3332.jpg    1024   1024
# 11495  image_6905.jpg    1024   1024
# 11496  image_4080.jpg    1024   1024
# 11497  image_8309.jpg    1024   1024
#
#                                                     bbox     age       race  \
# 0      [934.0000000000097, 144.82228672769534, 238.24...  20-30s  Caucasian
# 1      [1094.0513571635438, 422.91772295627203, 55.45...  20-30s  Caucasian
# 2      [419.93871061403877, 269.1250391680045, 377.19...  20-30s  Mongoloid
# 3      [549.169724453414, 92.52040334013152, 306.8821...  20-30s  Caucasian
# 4      [640.2165901410499, 619.7806050101991, 359.991...  20-30s  Mongoloid
# ...

# %%
each_emotion = unmark_df[unmark_df['emotion'] == 'Disgust'].file_name.values
# if len(each_emotion) > 400:
#   each_emotion

# %%
emotion_class
# Out:
# Index(['Happiness', 'Neutral', 'Sadness', 'Surprise', 'Anger', 'Disgust',
#        'Fear'],
#       dtype='object')

# %%
glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/*')

# %%
for emotion in emotion_class:
  print(emotion, len(glob(f'/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/{emotion}/*.jpg')))

  # each_emotion = unmark_df[unmark_df['emotion'] == emotion].file_name.values
  # if len(each_emotion) > 400:
  #   each_emotion = np.random.choice(each_emotion, 400, replace=False)
  # print(emotion, len(each_emotion))
# Out:
# Happiness 57
# Neutral 0
# Sadness 0
# Surprise 0
# Anger 0
# Disgust 0
# Fear 0

# %%
for emotion in emotion_class:
  each_emotion = unmark_df[unmark_df['emotion'] == emotion].file_name.values
  if len(each_emotion) > 600:
    each_emotion = np.random.choice(each_emotion, 600, replace=False)
  print(emotion, len(each_emotion))

  for each_img in each_emotion:
    if(os.path.isfile(f'/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/train_crop_align/{each_img}')):
      shutil.copyfile(f'/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/train_crop_align/{each_img}',
                      f'/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/{emotion}/{each_img}')
  print("Done ", emotion )
# Out:
# Happiness 600
# Done  Happiness
# Neutral 600
# Done  Neutral
# Sadness 270
# Done  Sadness
# Surprise 229
# Done  Surprise
# Anger 213
# Done  Anger
# Disgust 95
# Done  Disgust
# Fear 77
# Done  Fear

# %%
single_label.emotion.value_counts()
# Out:
# Happiness    7229
# Neutral      3729
# Sadness       296
# Anger         237
# Surprise      237
# Disgust       102
# Fear           81
# Name: emotion, dtype: int64

# %%
from tqdm import tqdm
from IPython.display import clear_output
import time

train_dir = '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/external_data/train/'
emotion_data_dir = '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_processed/emotion_data/train_processed/'

for i in tqdm(range(7229-237)):
 # try:
    if single_label.iloc[i,8] == 'Anger':
      shutil.copy(train_dir + f'/Anger/{single_label.iloc[i,0]}',
                  emotion_data_dir + f"Anger/{single_label.iloc[i,0]}")
    # elif single_label.iloc[i,8] == 'Fear':
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Fear/{single_label.iloc[i,0]}")
    # elif single_label.iloc[i,8] == 'Happiness':
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Happiness/{single_label.iloc[i,0]}")
    # elif single_label.iloc[i,8] == 'Sadness':
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Sadness/{single_label.iloc[i,0]}")
    # elif single_label.iloc[i,8] == 'Surprise':
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Surprise/{single_label.iloc[i,0]}")
    # elif single_label.iloc[i,8] == 'Neutral':
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Neutral/{single_label.iloc[i,0]}")
    # else:
    #   shutil.copy(train_dir + f'{single_label.iloc[i,0]}',
    #               emotion_data_dir + f"Disgust/{single_label.iloc[i,0]}")
  # except:
  #   continue
# Out:
#   0%|          | 20/6992 [00:00<00:02, 3382.23it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-8f90d1e73a9d> in <cell line: 8>()
#       9  # try:
#      10     if single_label.iloc[i,8] == 'Anger':
# ---> 11       shutil.copy(train_dir + f'/Anger/{single_label.iloc[i,0]}',
#      12                   emotion_data_dir + f"Anger/{single_label.iloc[i,0]}")
#      13     # elif single_label.iloc[i,8] == 'Fear':
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     252         os.symlink(os.readlink(src), dst)
# ...

# %%
all_dir = glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data_raw/private_test_3/data/*')
len(all_dir)
# Out:
# 12653

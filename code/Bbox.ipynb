# %%
import numpy as np
import pandas as pd
import cv2
import os

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
all_dir = glob('/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data/data/*.jpg')

# %%
dir = np.random.choice(all_dir)
dir
# Out:
# '/content/drive/MyDrive/AI_HACKATHON_NEWBEES/data/data/71242773.jpg'

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
import matplotlib.pyplot as plt
img = cv2.imread(dir)

img = cv2.cvtColor(img, cv2.IMREAD_GRAYSCALE)

faces = face_model.detectMultiScale(img,scaleFactor=1.1, minNeighbors=4)

out_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-ee0ffc44147d> in <cell line: 6>()
#       4 img = cv2.cvtColor(img, cv2.IMREAD_GRAYSCALE)
#       5
# ----> 6 faces = face_model.detectMultiScale(img,scaleFactor=1.1, minNeighbors=4)
#       7
#       8 out_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#
# error: OpenCV(4.8.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'
